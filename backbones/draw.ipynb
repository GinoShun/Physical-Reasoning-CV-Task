# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# Data for the new distribution
labels = ['Recommended', 'Not Recommended']
sizes = [83.4, 16.6]

# Create the pie chart with customized colors
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors=[ '#ff9999', '#66b3ff'])

# Set title
ax.set_title('Distribution of Labels')

# Display the plot
plt.show()
